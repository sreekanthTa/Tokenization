# %% [markdown]
# <a href="https://colab.research.google.com/github/sreekanthTa/Tokenization/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "datasets>=2.14" "sacremoses>=0.0.53" "tokenizers>=0.15" "transformers>=4.29"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.8/867.8 kB 15.9 MB/s eta 0:00:00
# ...
